# %%
import sumo_rl
import supersuit as ss
from stable_baselines3.common.vec_env import VecMonitor
import supersuit
from pettingzoo.utils.env import ParallelEnv

# %%
#A2C model 
import gym

from stable_baselines3 import A2C

env = sumo_rl.parallel_env(net_file='sumo-rl-master/nets/single-intersection/single-intersection.net.xml',
                  route_file='sumo-rl-master/nets/single-intersection/single-intersection.rou.xml',
                  use_gui=False,
                  delta_time = 10 ,
                  num_seconds= 20000) 

env = ss.pettingzoo_env_to_vec_env_v1(env)
env = ss.concat_vec_envs_v1(env, 2, num_cpus=1, base_class='stable_baselines3')
env = VecMonitor(env)

env.reset()

model = A2C('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=20000)
# Out:
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 88       |
# |    iterations         | 100      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.39    |
# |    explained_variance | 0.239    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.02     |
# |    value_loss         | 0.372    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 96       |
# |    iterations         | 200      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.379   |
# |    explained_variance | 0.542    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.169    |
# |    value_loss         | 0.266    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 300      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.33    |
# |    explained_variance | 0.616    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.00868  |
# |    value_loss         | 0.0208   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 400      |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.287   |
# |    explained_variance | -0.0391  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0176  |
# |    value_loss         | 0.0193   |
# ------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.31500033 |
# | time/                 |             |
# |    fps                | 100         |
# |    iterations         | 500         |
# |    time_elapsed       | 49          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -0.292      |
# |    explained_variance | 0.647       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -0.00132    |
# |    value_loss         | 0.0227      |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.31500033 |
# | time/                 |             |
# |    fps                | 102         |
# |    iterations         | 600         |
# |    time_elapsed       | 58          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -0.242      |
# |    explained_variance | -0.224      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -0.0151     |
# |    value_loss         | 0.01        |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.31500033 |
# | time/                 |             |
# |    fps                | 102         |
# |    iterations         | 700         |
# |    time_elapsed       | 68          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -0.247      |
# |    explained_variance | 0.312       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -0.018      |
# |    value_loss         | 0.0304      |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.31500033 |
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 800         |
# |    time_elapsed       | 77          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -0.254      |
# |    explained_variance | 0.497       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -0.00164    |
# |    value_loss         | 0.00997     |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.21000049 |
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 900         |
# |    time_elapsed       | 87          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -0.197      |
# |    explained_variance | -0.478      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 0.00391     |
# |    value_loss         | 0.0201      |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.21000049 |
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 1000        |
# |    time_elapsed       | 96          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -0.166      |
# |    explained_variance | 0.437       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | -0.00279    |
# |    value_loss         | 0.00917     |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.21000049 |
# | time/                 |             |
# |    fps                | 104         |
# |    iterations         | 1100        |
# |    time_elapsed       | 105         |
# |    total_timesteps    | 11000       |
# | train/                |             |
# |    entropy_loss       | -0.246      |
# |    explained_variance | -0.11       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | -0.235      |
# |    value_loss         | 0.287       |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.21000049 |
# | time/                 |             |
# |    fps                | 105         |
# |    iterations         | 1200        |
# |    time_elapsed       | 114         |
# |    total_timesteps    | 12000       |
# | train/                |             |
# |    entropy_loss       | -0.148      |
# |    explained_variance | 0.573       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | -0.00398    |
# |    value_loss         | 0.0056      |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.21833368 |
# | time/                 |             |
# |    fps                | 105         |
# |    iterations         | 1300        |
# |    time_elapsed       | 123         |
# |    total_timesteps    | 13000       |
# | train/                |             |
# |    entropy_loss       | -0.118      |
# |    explained_variance | 0.191       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1299        |
# |    policy_loss        | -0.0283     |
# |    value_loss         | 0.0173      |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.21833368 |
# | time/                 |             |
# |    fps                | 105         |
# |    iterations         | 1400        |
# |    time_elapsed       | 132         |
# |    total_timesteps    | 14000       |
# | train/                |             |
# |    entropy_loss       | -0.223      |
# |    explained_variance | 0.167       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | -0.00276    |
# |    value_loss         | 0.00499     |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.21833368 |
# | time/                 |             |
# |    fps                | 104         |
# |    iterations         | 1500        |
# |    time_elapsed       | 142         |
# |    total_timesteps    | 15000       |
# | train/                |             |
# |    entropy_loss       | -0.106      |
# |    explained_variance | 0.575       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | -0.0129     |
# |    value_loss         | 0.0319      |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.21833368 |
# | time/                 |             |
# |    fps                | 104         |
# |    iterations         | 1600        |
# |    time_elapsed       | 153         |
# |    total_timesteps    | 16000       |
# | train/                |             |
# |    entropy_loss       | -0.152      |
# |    explained_variance | 0.699       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | -0.0192     |
# |    value_loss         | 0.0056      |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.23875037 |
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 1700        |
# |    time_elapsed       | 164         |
# |    total_timesteps    | 17000       |
# | train/                |             |
# |    entropy_loss       | -0.126      |
# |    explained_variance | 0.514       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | -0.00248    |
# |    value_loss         | 0.00467     |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.23875037 |
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 1800        |
# |    time_elapsed       | 173         |
# |    total_timesteps    | 18000       |
# | train/                |             |
# |    entropy_loss       | -0.124      |
# |    explained_variance | -0.149      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | -0.00113    |
# |    value_loss         | 0.0167      |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.23875037 |
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 1900        |
# |    time_elapsed       | 183         |
# |    total_timesteps    | 19000       |
# | train/                |             |
# |    entropy_loss       | -0.138      |
# |    explained_variance | 0.501       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | -0.00299    |
# |    value_loss         | 0.0101      |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 2e+03       |
# |    ep_rew_mean        | -0.23875037 |
# | time/                 |             |
# |    fps                | 104         |
# |    iterations         | 2000        |
# |    time_elapsed       | 191         |
# |    total_timesteps    | 20000       |
# | train/                |             |
# |    entropy_loss       | -0.141      |
# |    explained_variance | 0.791       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 0.0137      |
# |    value_loss         | 0.0466      |
# ---------------------------------------

# %%
#DQN
import gym

from stable_baselines3 import DQN

env = sumo_rl.parallel_env(net_file='sumo-rl-master/nets/single-intersection/single-intersection.net.xml',
                  route_file='sumo-rl-master/nets/single-intersection/single-intersection.rou.xml',
                  use_gui=False,
                  delta_time = 10 ,
                  num_seconds= 20000) 

env = ss.pettingzoo_env_to_vec_env_v1(env)
env = ss.concat_vec_envs_v1(env, 2, num_cpus=3, base_class='stable_baselines3')
env = VecMonitor(env)

env.reset()

model = DQN('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=20000 )
# Out:
# Using cpu device
# ------------------------------------
# | rollout/            |            |
# |    ep_len_mean      | 2e+03      |
# |    ep_rew_mean      | -2.0199814 |
# |    exploration_rate | 0.05       |
# | time/               |            |
# |    episodes         | 4          |
# |    fps              | 105        |
# |    time_elapsed     | 76         |
# |    total_timesteps  | 8004       |
# ------------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | -4.64373 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 104      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 16008    |
# ----------------------------------

# %%
#PPO
import gym

from stable_baselines3 import PPO

env = sumo_rl.parallel_env(net_file='sumo-rl-master/nets/single-intersection/single-intersection.net.xml',
                  route_file='sumo-rl-master/nets/single-intersection/single-intersection.rou.xml',
                  use_gui=False,
                  delta_time = 10 ,
                  num_seconds= 20000) 

env = ss.pettingzoo_env_to_vec_env_v1(env)
env = ss.concat_vec_envs_v1(env, 2, num_cpus=3, base_class='stable_baselines3')
env = VecMonitor(env)

env.reset()

model = PPO('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=20000 )
# Out:
# Using cpu device
# -----------------------------------
# | rollout/           |            |
# |    ep_len_mean     | 2e+03      |
# |    ep_rew_mean     | -1.1399846 |
# | time/              |            |
# |    fps             | 105        |
# |    iterations      | 1          |
# |    time_elapsed    | 38         |
# |    total_timesteps | 4096       |
# -----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.5624845  |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 2           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018058034 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.676      |
# |    explained_variance   | -0.00627    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.7         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 22.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2.44499     |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 3            |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0068857423 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.664       |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4            |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0111      |
# |    value_loss           | 10.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.976242   |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 4           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009423692 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.55        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 4.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.8889936  |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 5           |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007840165 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.561       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.325       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 1.02        |
# -----------------------------------------
